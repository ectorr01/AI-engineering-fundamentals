# %% [markdown]
# # **Esercizio 5**
#
# Crea uno script completo che:
#
# 1.  Chiede all'utente una spiegazione o una curiosità.
#
# 2.   Usa l'input per passare la domanda a Claude
#
# 3.   Chiede all'utente se deve rispondere a un '*esperto' o a un 'bambino'.*
# 4.   Usa l'input per decidere il system promp da fargli utilizzare in base all'input scelto.
# 5.   Risponde alla domanda

# %%
# Installa la libreria Anthropic (necessario su Colab ad ogni sessione)
# !pip install anthropic -q
print("✅ Libreria installata!")
# Out:
# ✅ Libreria installata!

# %%
# Carica la API key dai Colab Secrets
from google.colab import userdata
import anthropic
import os

# Legge il secret che hai configurato
os.environ["ANTHROPIC_API_KEY"] = userdata.get("ANTHROPIC_API_KEY")

# Crea il client
client = anthropic.Anthropic()

# Verifica (senza stampare la chiave!)
key = os.environ.get("ANTHROPIC_API_KEY", "")
if key.startswith("sk-ant"):
    print(f"✅ API key configurata correttamente: sk-ant-...{key[-6:]}")
else:
    print("❌ API key non trovata. Controlla i Colab Secrets.")
# Out:
# ✅ API key configurata correttamente: sk-ant-...2vZAAA

# %%
def chiedi_claude(domanda, temperature=0.7, system=None, max_tokens=300):
    """Invia una domanda a Claude e restituisce la risposta testuale."""
    params = {
        "model": "claude-haiku-4-5-20251001",
        "max_tokens": max_tokens,
        "temperature": temperature,
        "messages": [{"role": "user", "content": domanda}]
    }
    if system:
        params["system"] = system

    response = client.messages.create(**params)
    return response.content[0].text

# %%
domanda = input("Scegli una domanda: ")
# Out:
# Scegli una domanda: Perchè il cielo è blu?

# %%
ruolo = input("Scegli il ruolo: esperto o bambino. ")

if ruolo == "bambino":
    system = "Sei un insegnante per bambini di 3 anni."

elif ruolo == "esperto":
    system = "Sei un professore universitario."
# Out:
# Scegli il ruolo: esperto o bambino. bambino

# %%
risposta = chiedi_claude(domanda, system=system)
print (risposta)
# Out:
# # Perché il cielo è blu? 🌤️
#
# Ciao! Te lo spiego in modo semplice!
#
# Immagina che la **luce del sole** sia come un arcobaleno con tanti colori tutti insieme. Quando questa luce scende dal cielo, incontra l'**aria** intorno a noi.
#
# L'aria ha tante piccolissime cose (che non vediamo) che giocano con la luce. Queste cose amano molto il **blu** e il **celeste** e li fanno rimbalzare dappertutto nel cielo!
#
# Gli altri colori (come il rosso e il giallo) passano dritti senza rimbalzare molto.
#
# **Ecco perché vediamo il cielo blu!** 💙
#
# ---
#
# ### Un gioco per capire meglio:
# Prova a guardare il cielo al **tramonto**: diventa arancione e rosso perché il sole è basso e la luce fa un percorso più lungo nell'aria. Allora vedrai altri colori!
#
# *Hai altre domande sul cielo?* 😊
